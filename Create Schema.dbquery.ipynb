-- %%
-- Create a dedicated project catalog and schema
CREATE CATALOG IF NOT EXISTS climate_portfolio;
USE CATALOG climate_portfolio;

CREATE SCHEMA IF NOT EXISTS global_warming;
USE SCHEMA global_warming;

-- Create a Volume to land our initial raw downloads
CREATE VOLUME IF NOT EXISTS climate_portfolio.global_warming.raw_landing;
